# %%
# download dependencies
from pandas import DataFrame, read_csv
import pandas as pd
from sqlalchemy import create_engine
from config import pw

# %%
# load data for 2006-21 ranking
file = r'political_and_civil_liberty/Aggregate_Category_and_Subcategory_Scores_FIW_2003-2021.xlsx'
df=pd.read_excel(file, 'FIW06-21')
df.head()
# Out:
#   Country/Territory   Region C/T?  Edition Status  PR Rating  CL Rating   A  \
# 0          Abkhazia  Eurasia    t     2021     PF          5          5   5
# 1       Afghanistan     Asia    c     2021     NF          5          6   3
# 2           Albania   Europe    c     2021     PF          3          3   8
# 3           Algeria     MENA    c     2021     NF          6          5   3
# 4           Andorra   Europe    c     2021      F          1          1  12
#
#     B   C  ...  Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  \
# 0   8   4  ...          NaN          NaN          NaN          NaN
# 1   7   3  ...          NaN          NaN          NaN          NaN
# 2  12   7  ...          NaN          NaN          NaN          NaN
# 3   4   3  ...          NaN          NaN          NaN          NaN
# 4  15  11  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  Unnamed: 34   x
# 0          NaN          NaN          NaN          NaN          NaN NaN
# 1          NaN          NaN          NaN          NaN          NaN NaN
# 2          NaN          NaN          NaN          NaN          NaN NaN
# 3          NaN          NaN          NaN          NaN          NaN NaN
# 4          NaN          NaN          NaN          NaN          NaN NaN
#
# [5 rows x 36 columns]

# %%
# drop columns where all rows have NaN
df.dropna(axis=1, how='all', inplace=True)
df.head()
# Out:
#   Country/Territory   Region C/T?  Edition Status  PR Rating  CL Rating   A  \
# 0          Abkhazia  Eurasia    t     2021     PF          5          5   5
# 1       Afghanistan     Asia    c     2021     NF          5          6   3
# 2           Albania   Europe    c     2021     PF          3          3   8
# 3           Algeria     MENA    c     2021     NF          6          5   3
# 4           Andorra   Europe    c     2021      F          1          1  12
#
#     B   C  Add Q  Add A  PR   D   E   F   G  CL  Total
# 0   8   4      0    NaN  17   8   6   4   5  23     40
# 1   7   3      0    NaN  13   6   4   2   2  14     27
# 2  12   7      0    NaN  27  13   8   9   9  39     66
# 3   4   3      0    NaN  10   6   3   6   7  22     32
# 4  15  11      0    NaN  38  14  11  15  15  55     93

# %%
# confirm that df has 3339 rows and 19 columns
df.shape
# Out:
# (3339, 19)

# %%
# replace spaces in column names with underscores
df.columns=df.columns.str.replace(' ','_')
df.head()
# Out:
#   Country/Territory   Region C/T?  Edition Status  PR_Rating  CL_Rating   A  \
# 0          Abkhazia  Eurasia    t     2021     PF          5          5   5
# 1       Afghanistan     Asia    c     2021     NF          5          6   3
# 2           Albania   Europe    c     2021     PF          3          3   8
# 3           Algeria     MENA    c     2021     NF          6          5   3
# 4           Andorra   Europe    c     2021      F          1          1  12
#
#     B   C  Add_Q  Add_A  PR   D   E   F   G  CL  Total
# 0   8   4      0    NaN  17   8   6   4   5  23     40
# 1   7   3      0    NaN  13   6   4   2   2  14     27
# 2  12   7      0    NaN  27  13   8   9   9  39     66
# 3   4   3      0    NaN  10   6   3   6   7  22     32
# 4  15  11      0    NaN  38  14  11  15  15  55     93

# %%
# save years in df as list
years_list=df.Edition.unique().tolist()
years_list
# Out:
# [2021,
#  2020,
#  2019,
#  2018,
#  2017,
#  2016,
#  2015,
#  2014,
#  2013,
#  2012,
#  2011,
#  2010,
#  2009,
#  2008,
#  2007,
#  2006]

# %%
# create connection string to database
db_string = f'postgresql://postgres:{pw}@127.0.0.1:5432/freedom_in_the_world_index'
# create database engine
engine = create_engine(db_string)

# %%
# load df into SQL database and save csv files

df_list=[]

for year in years_list:
    # filter df for year
    df_year = df[df["Edition"]==year]
    
    # append filtered df to list
    df_list.append(df_year)
    
    # rename 'Total' column
    df_year.rename(columns = {'Total':f'Score'+str(year)}, inplace=True)

    # rename 'Status' column
    df_year.rename(columns = {'Status':f'Status'+str(year)}, inplace=True)
        
    #load into database
    df_year.to_sql(name=f'index'+str(year),con=engine, if_exists='replace', index=False)
    
    # save csv file for each year
    df_year.to_csv('political_and_civil_liberty/csv/FIW_index'+str(year)+'_data.csv', header=True, index=False)
# Out:
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\itote\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_list[0]
# Out:
#     Country/Territory   Region C/T?  Edition Status2021  PR_Rating  CL_Rating  \
# 0            Abkhazia  Eurasia    t     2021         PF          5          5
# 1         Afghanistan     Asia    c     2021         NF          5          6
# 2             Albania   Europe    c     2021         PF          3          3
# 3             Algeria     MENA    c     2021         NF          6          5
# 4             Andorra   Europe    c     2021          F          1          1
# ..                ...      ...  ...      ...        ...        ...        ...
# 205         West Bank     MENA    t     2021         NF          7          5
# 206    Western Sahara     MENA    t     2021         NF          7          7
# 207             Yemen     MENA    c     2021         NF          7          6
# 208            Zambia      SSA    c     2021         PF          4          4
# 209          Zimbabwe      SSA    c     2021         NF          6          5
#
#       A   B   C  Add_Q  Add_A  PR   D   E   F   G  CL  Score2021
# 0     5   8   4      0    NaN  17   8   6   4   5  23         40
# 1     3   7   3      0    NaN  13   6   4   2   2  14         27
# 2     8  12   7      0    NaN  27  13   8   9   9  39         66
# 3     3   4   3      0    NaN  10   6   3   6   7  22         32
# 4    12  15  11      0    NaN  38  14  11  15  15  55         93
# ..   ..  ..  ..    ...    ...  ..  ..  ..  ..  ..  ..        ...
# 205   1   4   2      3    NaN   4   7   5   4   5  21         25
# 206   0   0   0      3    NaN  -3   3   0   0   4   7          4
# 207   0   1   0      0    NaN   1   3   3   2   2  10         11
# 208   6  10   4      0    NaN  20   9   7   8   8  32         52
# 209   3   5   3      0    NaN  11   7   3   2   5  17         28
#
# [210 rows x 19 columns]
