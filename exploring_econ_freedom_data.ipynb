# %%
# download dependencies
from pandas import DataFrame, read_csv
import pandas as pd
from sqlalchemy import create_engine
from config import pw

# %%
# create connection string to database
db_string = f'postgresql://postgres:{pw}@127.0.0.1:5432/economic_freedom_index'
# create database engine
engine = create_engine(db_string)

# %%
# load 2013-2021 data, remove spaces, save as csv files

# create empty list to append dataframe names
index_list=[]

# loop through years
for i in range(2013,2022): 
    # load data into df and append to list
    file = r'economic_freedom/data/xls/index'+str(i)+'_data.xls'
    index_list.append(pd.read_excel(file))
    
    # remove spaces and replace with underscore in df column names
    index_list[i-2013].columns = index_list[i-2013].columns.str.replace(' ','_')
    
    # load index df into database
    #index_list[i-2013].to_sql(name=f'index'+str(i), con=engine, if_exists='replace')
   # index_list[0].to_sql(name='test', con=engine, if_exists='replace')
    
    # save as csv file
   # index_list[i-2013].to_csv('economic_freedom/data/csv/index'+str(i)+'_data.csv', header=True, index=False)

# %%
index_list[0]
# Out:
#      CountryID Country_Name      WEBNAME  \
# 0            1  Afghanistan  Afghanistan
# 1            2      Albania      Albania
# 2            3      Algeria      Algeria
# 3            4       Angola       Angola
# 4            5    Argentina    Argentina
# ..         ...          ...          ...
# 180        181        Yemen        Yemen
# 181        182       Zambia       Zambia
# 182        183     Zimbabwe     Zimbabwe
# 183        184      Somalia      Somalia
# 184        185       Kosovo       Kosovo
#
#                                     Region  World_Rank  Region_Rank  \
# 0                             Asia-Pacific         NaN          NaN
# 1                                   Europe        58.0         27.0
# 2               Middle East / North Africa       145.0         14.0
# 3                       Sub-Saharan Africa       158.0         40.0
# 4    South and Central America / Caribbean       160.0         27.0
# ..                                     ...         ...          ...
# 180             Middle East / North Africa       113.0         12.0
# 181                     Sub-Saharan Africa        93.0         12.0
# 182                     Sub-Saharan Africa       175.0         46.0
# 183                     Sub-Saharan Africa         NaN          NaN
# 184                                 Europe         NaN          NaN
#
#      2013_Score  Change_in_Yearly_Score_from_2012  Property_Rights  \
# 0           NaN                               NaN              NaN
# 1          65.2                               0.1             30.0
# 2          49.6                              -1.4             30.0
# 3          47.3                               0.6             15.0
# 4          46.7                              -1.3             15.0
# ..          ...                               ...              ...
# 180        55.9                               0.6             30.0
# 181        58.7                               0.4             30.0
# 182        28.6                               2.3             10.0
# 183         NaN                               NaN              NaN
# 184         NaN                               NaN             30.0
#
#      Change_in_Property_Rights_from_2012  ...      Country  \
# 0                                    NaN  ...  Afghanistan
# 1                                   -5.0  ...      Albania
# 2                                    0.0  ...      Algeria
# 3                                   -5.0  ...       Angola
# 4                                   -5.0  ...    Argentina
# ..                                   ...  ...          ...
# 180                                  0.0  ...        Yemen
# 181                                  0.0  ...       Zambia
# 182                                  0.0  ...     Zimbabwe
# 183                                  NaN  ...      Somalia
# 184                                  NaN  ...       Kosovo
#
#      Population_(Millions)  GDP_(Billions,_PPP)  GDP_Growth_Rate_(%)  \
# 0                   31.084               29.731                5.737
# 1                    3.218               24.910                2.000
# 2                   35.954              263.661                2.470
# 3                   19.625              115.679                3.404
# 4                   40.900              716.419                8.870
# ..                     ...                  ...                  ...
# 180                 25.130               57.966              -10.480
# 181                 13.585               21.882                6.565
# 182                 12.575                6.127                9.319
# 183                  9.100                6.100                2.600
# 184                  1.700               11.990                5.200
#
#      5_Year_GDP_Growth_Rate_(%)  GDP_per_Capita_(PPP)  Unemployment_(%)  \
# 0                     10.335398               956.448               NaN
# 1                      4.431419              7741.428              13.5
# 2                      2.718594              7333.226              10.0
# 3                      8.848807              5894.617               NaN
# 4                      6.811779             17516.147               7.2
# ..                          ...                   ...               ...
# 180                    1.411758              2306.695               NaN
# 181                    6.490851              1610.722              14.0
# 182                   -0.145682               487.197              95.0
# 183                         NaN               600.000               NaN
# 184                         NaN              7052.000              45.1
#
#      Inflation_(%)  FDI_Inflow_(Millions)  Public_Debt_(%_of_GDP)
# 0           11.247              83.411455                  12.100
# 1            3.427            1031.362818                  58.923
# 2            4.500            2571.000000                   9.925
# 3           13.500           -5585.529270                  30.897
# 4            9.775            7243.148181                  44.203
# ..             ...                    ...                     ...
# 180         17.610            -712.810000                  42.522
# 181          8.659            1981.700000                  26.072
# 182          3.470             387.000000                  70.328
# 183            NaN             102.000000                     NaN
# 184          7.300             473.000000                   5.600
#
# [185 rows x 43 columns]
